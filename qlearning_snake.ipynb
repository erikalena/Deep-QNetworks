# %% [markdown]
# ## Q-Learning in Snake
#
#
# Start by standard configuration we saw for the simple example of the cliff presented in Sutton and Burto Ex.6.6.
# This time we will use a different environment, the snake game.

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

from qlearning import *

# %%
# The list of actions I can take: 
#Actions = [Down,  Up,  Right,Left]
Actions  = np.array([[1,0],[-1,0],[0,1],[0,-1]])

Lx = 10
Ly = 10


# state/action space = [ Lx * Ly, 4]
policy = np.zeros( (Ly,Lx,4) )
policy[:,:] = [0.25, 0.25, 0.25, 0.25]


env = GridWorldEnv(Lx,Ly)
env.render()

# %%
# learn policies
env.learn_policies()
# Out:
# Policy for initial state [*,0] and final state is saved
# Policy for initial state [*,1] and final state is saved
# Policy for initial state [*,2] and final state is saved
# Policy for initial state [*,3] and final state is saved
# Policy for initial state [*,4] and final state is saved
# Policy for initial state [*,5] and final state is saved
# Policy for initial state [*,6] and final state is saved
# Policy for initial state [*,7] and final state is saved
# Policy for initial state [*,8] and final state is saved
# Policy for initial state [*,9] and final state is saved

# %%
env.render_policy(goal_idx=45) # random index for reward
